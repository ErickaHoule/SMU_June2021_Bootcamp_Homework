# %%
import pandas as pd

# %%
df = pd.read_csv("assets/data/cities_elh.csv")
df.head()
# Out:
#       City Country      Lat       Lng  Temperature  Humidity  Clouds  \
# 0    Lagoa      PT  39.0500  -27.9833        20.37        75     100
# 1  Qaanaaq      GL  77.4840  -69.3632        -7.47        86      98
# 2     Nome      US  64.5011 -165.4064         8.04        87      90
# 3     Faya      SA  18.3851   42.4509        15.29        47       9
# 4   Albany      US  42.6001  -73.9662        17.95        93     100
#
#    Wind_Speed        date
# 0        7.54  1630898843
# 1        0.94  1630898844
# 2        3.09  1630898844
# 3        0.96  1630898844
# 4        1.34  1630898681

# %%
html_table=df.to_html()
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Clouds</th>
#       <th>Wind_Speed</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lagoa</td>
#       <td>PT</td>
#       <td>39.0500</td>
#       <td>-27.9833</td>
#       <td>20.37</td>
#       <td>75</td>
#       <td>100</td>
#       <td>7.54</td>
#       <td>1630898843</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Qaanaaq</td>
#       <td>GL</td>
#       <td>77.4840</td>
#       <td>-69.3632</td>
#       <td>-7.47</td>
#       <td>86</td>
#       <td>98</td>
#       <td>0.94</td>
#       <td>1630898844</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Nome</td>
#       <td>US</td>
#       <td>64.5011</td>
#       <td>-165.4064</td>
# ...
