# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("/content/drive/MyDrive/Colab/21-Deep-Learning/Instructions/Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EIN                     34299 non-null  int64
#  1   NAME                    34299 non-null  object
#  2   APPLICATION_TYPE        34299 non-null  object
#  3   AFFILIATION             34299 non-null  object
#  4   CLASSIFICATION          34299 non-null  object
#  5   USE_CASE                34299 non-null  object
#  6   ORGANIZATION            34299 non-null  object
#  7   STATUS                  34299 non-null  int64
#  8   INCOME_AMT              34299 non-null  object
#  9   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  10  ASK_AMT                 34299 non-null  int64
#  11  IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 3.1+ MB

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION  ... ASK_AMT IS_SUCCESSFUL
# 0              T10       Independent  ...    5000             1
# 1               T3       Independent  ...  108590             1
# 2               T5  CompanySponsored  ...    5000             0
# 3               T3  CompanySponsored  ...    6692             1
# 4               T3       Independent  ...  142590             1
#
# [5 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
for col in application_df.columns:
  if col not in ["STATUS", "ASK_AMT"]:
    print(col)
    print(len(application_df[col].value_counts()))
    print()
# Out:
# APPLICATION_TYPE
# 17
#
# AFFILIATION
# 6
#
# CLASSIFICATION
# 71
#
# USE_CASE
# 5
#
# ORGANIZATION
# 4
#
# INCOME_AMT
# 9
#
# SPECIAL_CONSIDERATIONS
# 2
#
# IS_SUCCESSFUL
# 2

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.APPLICATION_TYPE.value_counts().plot(kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
app_vals = application_df.APPLICATION_TYPE.value_counts()
(app_vals[app_vals < 500].index)
# Out:
# Index(['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T15', 'T29', 'T17'], dtype='object')

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_vals = application_df.APPLICATION_TYPE.value_counts()

cutoff = 500
application_types_to_replace = list(app_vals[app_vals < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.CLASSIFICATION.value_counts().plot.kde()
plt.show()

# %%
# Look at CLASSIFICATION value counts for binning

class_vals1=application_df["CLASSIFICATION"].value_counts()
class_vals1.head(50)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1257        5
# C1600        5
# C2710        3
# C1260        3
# C0           3
# C3200        2
# C1246        2
# C1256        2
# C1234        2
# C1267        2
# C4120        1
# C2570        1
# C4500        1
# C1820        1
# C2170        1
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_vals = application_df.CLASSIFICATION.value_counts()
class_vals[class_vals > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1257        5
# C1600        5
# C2710        3
# C1260        3
# C0           3
# C3200        2
# C1246        2
# C1256        2
# C1234        2
# C1267        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Determine which values to replace if counts are less than ..?
replace_class= class_vals[class_vals < 500].index.tolist()

# Replace in dataframe
for clase in replace_class:
    application_df.CLASSIFICATION= application_df.CLASSIFICATION.replace(clase, "Other")
    
# Check to make sure binning was successful
application_df.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                         1                         0
# 1       1   108590  ...                         1                         0
# 2       1     5000  ...                         1                         0
# 3       1     6692  ...                         1                         0
# 4       1   142590  ...                         1                         0
#
# [5 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop("IS_SUCCESSFUL", axis=1) 
y = application_df.IS_SUCCESSFUL

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(len(application_df.columns))
# Out:
# 45

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3600
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,061
# Trainable params: 6,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
os.makedirs("/content/drive/MyDrive/Colab/21-Deep-Learning/Instructions/checkpoints/",exist_ok=True)
checkpoint_path = "/content/drive/MyDrive/Colab/21-Deep-Learning/Instructions/checkpoints/weights.{epoch:02d}.hdf5"

nn.compile(loss="binary_crossentropy", optimizer="adam", metrics= ["accuracy"])

cp_callback= ModelCheckpoint(filepath=checkpoint_path,save_weights_only=True, save_freq=5)

# %%
# Train the model
fit_model= nn.fit(X_train_scaled, y_train, epochs=100, verbose=1, callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 5ms/step - loss: 0.5727 - accuracy: 0.7185
# Epoch 2/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5553 - accuracy: 0.7271
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5521 - accuracy: 0.7300
# Epoch 4/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5509 - accuracy: 0.7305
# Epoch 5/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5493 - accuracy: 0.7305
# Epoch 6/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5476 - accuracy: 0.7317
# Epoch 7/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5473 - accuracy: 0.7319
# Epoch 8/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5468 - accuracy: 0.7321
# Epoch 9/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5456 - accuracy: 0.7324
# Epoch 10/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5456 - accuracy: 0.7331
# Epoch 11/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5446 - accuracy: 0.7308
# Epoch 12/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5445 - accuracy: 0.7337
# Epoch 13/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5437 - accuracy: 0.7331
# Epoch 14/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5436 - accuracy: 0.7337
# Epoch 15/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5431 - accuracy: 0.7362
# Epoch 16/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5434 - accuracy: 0.7340
# Epoch 17/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5421 - accuracy: 0.7338
# Epoch 18/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5425 - accuracy: 0.7356
# Epoch 19/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5421 - accuracy: 0.7353
# Epoch 20/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5417 - accuracy: 0.7355
# Epoch 21/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5415 - accuracy: 0.7358
# Epoch 22/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5408 - accuracy: 0.7354
# Epoch 23/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5410 - accuracy: 0.7358
# Epoch 24/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5406 - accuracy: 0.7363
# Epoch 25/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5406 - accuracy: 0.7362
# Epoch 26/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5403 - accuracy: 0.7370
# Epoch 27/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5396 - accuracy: 0.7360
# Epoch 28/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5399 - accuracy: 0.7367
# Epoch 29/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5393 - accuracy: 0.7367
# Epoch 30/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5396 - accuracy: 0.7377
# Epoch 31/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5391 - accuracy: 0.7365
# Epoch 32/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5390 - accuracy: 0.7380
# Epoch 33/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5390 - accuracy: 0.7369
# Epoch 34/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5390 - accuracy: 0.7378
# Epoch 35/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5383 - accuracy: 0.7374
# Epoch 36/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5381 - accuracy: 0.7378
# Epoch 37/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5384 - accuracy: 0.7385
# Epoch 38/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5381 - accuracy: 0.7375
# Epoch 39/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5379 - accuracy: 0.7378
# Epoch 40/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5375 - accuracy: 0.7389
# Epoch 41/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5380 - accuracy: 0.7381
# Epoch 42/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5377 - accuracy: 0.7383
# Epoch 43/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5373 - accuracy: 0.7379
# Epoch 44/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5372 - accuracy: 0.7382
# Epoch 45/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5369 - accuracy: 0.7380
# Epoch 46/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5369 - accuracy: 0.7388
# Epoch 47/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 48/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5367 - accuracy: 0.7385
# Epoch 49/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5368 - accuracy: 0.7389
# Epoch 50/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5364 - accuracy: 0.7389
# Epoch 51/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5363 - accuracy: 0.7392
# Epoch 52/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5364 - accuracy: 0.7378
# Epoch 53/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5360 - accuracy: 0.7393
# Epoch 54/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5363 - accuracy: 0.7392
# Epoch 55/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 56/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5359 - accuracy: 0.7394
# Epoch 57/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 58/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5355 - accuracy: 0.7392
# Epoch 59/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5361 - accuracy: 0.7392
# Epoch 60/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5357 - accuracy: 0.7391
# Epoch 61/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5354 - accuracy: 0.7390
# Epoch 62/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5352 - accuracy: 0.7390
# Epoch 63/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5354 - accuracy: 0.7397
# Epoch 64/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5352 - accuracy: 0.7385
# Epoch 65/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5352 - accuracy: 0.7398
# Epoch 66/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5351 - accuracy: 0.7396
# Epoch 67/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5352 - accuracy: 0.7388
# Epoch 68/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 69/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5353 - accuracy: 0.7388
# Epoch 70/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5347 - accuracy: 0.7406
# Epoch 71/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 72/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5345 - accuracy: 0.7390
# Epoch 73/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5349 - accuracy: 0.7395
# Epoch 74/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5348 - accuracy: 0.7394
# Epoch 75/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5345 - accuracy: 0.7397
# Epoch 76/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5345 - accuracy: 0.7398
# Epoch 77/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5345 - accuracy: 0.7404
# Epoch 78/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5344 - accuracy: 0.7402
# Epoch 79/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5343 - accuracy: 0.7398
# Epoch 80/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5348 - accuracy: 0.7402
# Epoch 81/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 82/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5341 - accuracy: 0.7394
# Epoch 83/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5337 - accuracy: 0.7396
# Epoch 84/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5338 - accuracy: 0.7406
# Epoch 85/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5343 - accuracy: 0.7401
# Epoch 86/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5341 - accuracy: 0.7405
# Epoch 87/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5335 - accuracy: 0.7400
# Epoch 88/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5341 - accuracy: 0.7402
# Epoch 89/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5335 - accuracy: 0.7399
# Epoch 90/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5340 - accuracy: 0.7405
# Epoch 91/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5339 - accuracy: 0.7409
# Epoch 92/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5336 - accuracy: 0.7400
# Epoch 93/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5335 - accuracy: 0.7407
# Epoch 94/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5339 - accuracy: 0.7389
# Epoch 95/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5334 - accuracy: 0.7405
# Epoch 96/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5332 - accuracy: 0.7403
# Epoch 97/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5335 - accuracy: 0.7386
# Epoch 98/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 99/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5334 - accuracy: 0.7399
# Epoch 100/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5335 - accuracy: 0.7392

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5594 - accuracy: 0.7308 - 313ms/epoch - 1ms/step
# Loss: 0.5594382882118225, Accuracy: 0.7308454513549805

# %%
# Export our model to HDF5 file
nn.save("/content/drive/MyDrive/Colab/21-Deep-Learning/Instructions/AlphabetSoupCharity.h5")
